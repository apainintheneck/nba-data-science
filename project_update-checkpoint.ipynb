# %% [markdown]
# Project Update
# Date: 06/08/2021
# Team: Bryce Randolph, Jeannie Davis, Harsandeep Singh, Kevin Robell

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
import seaborn as sns
sns.set()
rcParams['figure.figsize'] = 8,6
sns.set_context('talk')   # 'talk' for slightly larger

# %% [markdown]
# Choice of Dataset We decided to use the dataset at https://www.kaggle.com/nathanlauga/nba-games and we are only using the games.csv file. Drop that file in the same folder as this file to run the following code.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/harsandeep1/cst383-final-project/main/games.csv")
df = df[df.SEASON == 2019]

# %%
df
# Out:
#       GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 1206     2020-10-11  41900406            Final    1610612748       1610612747
# 1207     2020-10-09  41900405            Final    1610612747       1610612748
# 1208     2020-10-06  41900404            Final    1610612748       1610612747
# 1209     2020-10-04  41900403            Final    1610612748       1610612747
# 1210     2020-10-02  41900402            Final    1610612747       1610612748
# ...             ...       ...              ...           ...              ...
# 17673    2019-10-05  11900005            Final    1610612754       1610612758
# 17674    2019-10-05  11900006            Final    1610612744       1610612747
# 17675    2019-10-05  11900007            Final    1610612759       1610612753
# 17676    2019-10-04  11900002            Final    1610612746       1610612745
# 17677    2019-10-04  11900003            Final    1610612758       1610612754
#
#        SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  \
# 1206     2019    1610612748      93.0        0.443        0.591  ...
# 1207     2019    1610612747     108.0        0.463        0.857  ...
# 1208     2019    1610612748      96.0        0.427        0.808  ...
# 1209     2019    1610612748     115.0        0.513        0.913  ...
# 1210     2019    1610612747     124.0        0.505        0.588  ...
# ...       ...           ...       ...          ...          ...  ...
# 17673    2019    1610612754     130.0        0.521        0.944  ...
# 17674    2019    1610612744     101.0        0.393        0.769  ...
# 17675    2019    1610612759      89.0        0.388        0.750  ...
# 17676    2019    1610612746      96.0        0.384        0.600  ...
# 17677    2019    1610612758     131.0        0.494        0.778  ...
#
#        AST_home  REB_home  TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  \
# 1206       25.0      41.0    1610612747     106.0        0.483        0.643
# 1207       21.0      41.0    1610612748     111.0        0.458        0.955
# 1208       18.0      39.0    1610612747     102.0        0.443        0.857
# 1209       25.0      37.0    1610612747     104.0        0.430        0.759
# 1210       32.0      44.0    1610612748     114.0        0.507        0.912
# ...         ...       ...           ...       ...          ...          ...
# 17673      35.0      51.0    1610612758     106.0        0.378        0.780
# 17674      20.0      47.0    1610612747     123.0        0.475        0.633
# 17675      22.0      40.0    1610612753     125.0        0.526        0.714
# 17676      26.0      49.0    1610612745     109.0        0.375        0.800
# 17677      30.0      30.0    1610612754     132.0        0.516        0.788
#
#        FG3_PCT_away  AST_away  REB_away  HOME_TEAM_WINS
# 1206          0.314      23.0      46.0               0
# 1207          0.424      26.0      35.0               0
# 1208          0.359      25.0      42.0               0
# 1209          0.333      23.0      43.0               1
# 1210          0.407      29.0      37.0               1
# ...             ...       ...       ...             ...
# 17673         0.353      24.0      35.0               1
# 17674         0.303      32.0      58.0               0
# 17675         0.361      29.0      47.0               0
# 17676         0.229      21.0      52.0               0
# 17677         0.370      26.0      47.0               0
#
# [1241 rows x 21 columns]

# %% [markdown]
# what it is you are going to predict HOME_TEAM_WINS

# %%
df.info() # Basic data exploration
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1241 entries, 1206 to 17677
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GAME_DATE_EST     1241 non-null   object
#  1   GAME_ID           1241 non-null   int64
#  2   GAME_STATUS_TEXT  1241 non-null   object
#  3   HOME_TEAM_ID      1241 non-null   int64
#  4   VISITOR_TEAM_ID   1241 non-null   int64
#  5   SEASON            1241 non-null   int64
#  6   TEAM_ID_home      1241 non-null   int64
#  7   PTS_home          1241 non-null   float64
#  8   FG_PCT_home       1241 non-null   float64
#  9   FT_PCT_home       1241 non-null   float64
#  10  FG3_PCT_home      1241 non-null   float64
#  11  AST_home          1241 non-null   float64
#  12  REB_home          1241 non-null   float64
#  13  TEAM_ID_away      1241 non-null   int64
#  14  PTS_away          1241 non-null   float64
#  15  FG_PCT_away       1241 non-null   float64
#  16  FT_PCT_away       1241 non-null   float64
#  17  FG3_PCT_away      1241 non-null   float64
#  18  AST_away          1241 non-null   float64
#  19  REB_away          1241 non-null   float64
#  20  HOME_TEAM_WINS    1241 non-null   int64
# dtypes: float64(12), int64(7), object(2)
# memory usage: 213.3+ KB

# %%
df.describe() #Basic data Exploration
# Out:
#             GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID  SEASON  TEAM_ID_home  \
# count  1.241000e+03  1.241000e+03     1.241000e+03  1241.0  1.241000e+03
# mean   2.247261e+07  1.610613e+09     1.610613e+09  2019.0  1.610613e+09
# std    5.922460e+06  8.505847e+00     8.505253e+00     0.0  8.505847e+00
# min    1.190000e+07  1.610613e+09     1.610613e+09  2019.0  1.610613e+09
# 25%    2.190021e+07  1.610613e+09     1.610613e+09  2019.0  1.610613e+09
# 50%    2.190052e+07  1.610613e+09     1.610613e+09  2019.0  1.610613e+09
# 75%    2.190083e+07  1.610613e+09     1.610613e+09  2019.0  1.610613e+09
# max    5.190011e+07  1.610613e+09     1.610613e+09  2019.0  1.610613e+09
#
#           PTS_home  FG_PCT_home  FT_PCT_home  FG3_PCT_home     AST_home  \
# count  1241.000000  1241.000000  1241.000000   1241.000000  1241.000000
# mean    112.274778     0.463043     0.769757      0.359782    24.710717
# std      12.781012     0.056152     0.098386      0.085668     4.850270
# min      68.000000     0.269000     0.400000      0.118000    11.000000
# 25%     104.000000     0.425000     0.706000      0.300000    21.000000
# 50%     112.000000     0.462000     0.778000      0.359000    25.000000
# 75%     120.000000     0.505000     0.838000      0.417000    28.000000
# max     158.000000     0.633000     1.000000      0.629000    43.000000
#
#           REB_home  TEAM_ID_away     PTS_away  FG_PCT_away  FT_PCT_away  \
# count  1241.000000  1.241000e+03  1241.000000  1241.000000  1241.000000
# mean     45.438356  1.610613e+09   110.466559     0.455907     0.771137
# std       6.845032  8.505253e+00    12.447984     0.054403     0.102825
# min      24.000000  1.610613e+09    70.000000     0.308000     0.375000
# 25%      41.000000  1.610613e+09   102.000000     0.418000     0.706000
# 50%      45.000000  1.610613e+09   110.000000     0.455000     0.774000
# 75%      50.000000  1.610613e+09   119.000000     0.494000     0.840000
# max      67.000000  1.610613e+09   159.000000     0.674000     1.000000
#
#        FG3_PCT_away     AST_away     REB_away  HOME_TEAM_WINS
# count   1241.000000  1241.000000  1241.000000     1241.000000
# mean       0.353089    23.791297    44.197421        0.536664
# std        0.084250     4.851417     6.680293        0.498855
# min        0.094000    10.000000    25.000000        0.000000
# 25%        0.297000    20.000000    40.000000        0.000000
# 50%        0.353000    24.000000    44.000000        1.000000
# 75%        0.406000    27.000000    48.000000        1.000000
# max        0.680000    40.000000    65.000000        1.000000

# %%
df.isna().sum() # Shows that data doesn't have NA values.
# Out:
# GAME_DATE_EST       0
# GAME_ID             0
# GAME_STATUS_TEXT    0
# HOME_TEAM_ID        0
# VISITOR_TEAM_ID     0
# SEASON              0
# TEAM_ID_home        0
# PTS_home            0
# FG_PCT_home         0
# FT_PCT_home         0
# FG3_PCT_home        0
# AST_home            0
# REB_home            0
# TEAM_ID_away        0
# PTS_away            0
# FG_PCT_away         0
# FT_PCT_away         0
# FG3_PCT_away        0
# AST_away            0
# REB_away            0
# HOME_TEAM_WINS      0
# dtype: int64

# %%
np.count_nonzero(df, axis = 0)
# Out:
# array([1241, 1241, 1241, 1241, 1241, 1241, 1241, 1241, 1241, 1241, 1241,
#        1241, 1241, 1241, 1241, 1241, 1241, 1241, 1241, 1241,  666],
#       dtype=int64)

# %%
df.dropna(axis = 1)#remove columns with missing data
# Out:
#       GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 1206     2020-10-11  41900406            Final    1610612748       1610612747
# 1207     2020-10-09  41900405            Final    1610612747       1610612748
# 1208     2020-10-06  41900404            Final    1610612748       1610612747
# 1209     2020-10-04  41900403            Final    1610612748       1610612747
# 1210     2020-10-02  41900402            Final    1610612747       1610612748
# ...             ...       ...              ...           ...              ...
# 17673    2019-10-05  11900005            Final    1610612754       1610612758
# 17674    2019-10-05  11900006            Final    1610612744       1610612747
# 17675    2019-10-05  11900007            Final    1610612759       1610612753
# 17676    2019-10-04  11900002            Final    1610612746       1610612745
# 17677    2019-10-04  11900003            Final    1610612758       1610612754
#
#        SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  \
# 1206     2019    1610612748      93.0        0.443        0.591  ...
# 1207     2019    1610612747     108.0        0.463        0.857  ...
# 1208     2019    1610612748      96.0        0.427        0.808  ...
# 1209     2019    1610612748     115.0        0.513        0.913  ...
# 1210     2019    1610612747     124.0        0.505        0.588  ...
# ...       ...           ...       ...          ...          ...  ...
# 17673    2019    1610612754     130.0        0.521        0.944  ...
# 17674    2019    1610612744     101.0        0.393        0.769  ...
# 17675    2019    1610612759      89.0        0.388        0.750  ...
# 17676    2019    1610612746      96.0        0.384        0.600  ...
# 17677    2019    1610612758     131.0        0.494        0.778  ...
#
#        AST_home  REB_home  TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  \
# 1206       25.0      41.0    1610612747     106.0        0.483        0.643
# 1207       21.0      41.0    1610612748     111.0        0.458        0.955
# 1208       18.0      39.0    1610612747     102.0        0.443        0.857
# 1209       25.0      37.0    1610612747     104.0        0.430        0.759
# 1210       32.0      44.0    1610612748     114.0        0.507        0.912
# ...         ...       ...           ...       ...          ...          ...
# 17673      35.0      51.0    1610612758     106.0        0.378        0.780
# 17674      20.0      47.0    1610612747     123.0        0.475        0.633
# 17675      22.0      40.0    1610612753     125.0        0.526        0.714
# 17676      26.0      49.0    1610612745     109.0        0.375        0.800
# 17677      30.0      30.0    1610612754     132.0        0.516        0.788
#
#        FG3_PCT_away  AST_away  REB_away  HOME_TEAM_WINS
# 1206          0.314      23.0      46.0               0
# 1207          0.424      26.0      35.0               0
# 1208          0.359      25.0      42.0               0
# 1209          0.333      23.0      43.0               1
# 1210          0.407      29.0      37.0               1
# ...             ...       ...       ...             ...
# 17673         0.353      24.0      35.0               1
# 17674         0.303      32.0      58.0               0
# 17675         0.361      29.0      47.0               0
# 17676         0.229      21.0      52.0               0
# 17677         0.370      26.0      47.0               0
#
# [1241 rows x 21 columns]

# %%
df.drop(['GAME_DATE_EST', 'GAME_STATUS_TEXT', 'HOME_TEAM_ID', 'VISITOR_TEAM_ID'], axis = 1) #remove columns that are not relevant
# Out:
#         GAME_ID  SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  \
# 1206   41900406    2019    1610612748      93.0        0.443        0.591
# 1207   41900405    2019    1610612747     108.0        0.463        0.857
# 1208   41900404    2019    1610612748      96.0        0.427        0.808
# 1209   41900403    2019    1610612748     115.0        0.513        0.913
# 1210   41900402    2019    1610612747     124.0        0.505        0.588
# ...         ...     ...           ...       ...          ...          ...
# 17673  11900005    2019    1610612754     130.0        0.521        0.944
# 17674  11900006    2019    1610612744     101.0        0.393        0.769
# 17675  11900007    2019    1610612759      89.0        0.388        0.750
# 17676  11900002    2019    1610612746      96.0        0.384        0.600
# 17677  11900003    2019    1610612758     131.0        0.494        0.778
#
#        FG3_PCT_home  AST_home  REB_home  TEAM_ID_away  PTS_away  FG_PCT_away  \
# 1206          0.357      25.0      41.0    1610612747     106.0        0.483
# 1207          0.368      21.0      41.0    1610612748     111.0        0.458
# 1208          0.344      18.0      39.0    1610612747     102.0        0.443
# 1209          0.353      25.0      37.0    1610612747     104.0        0.430
# 1210          0.340      32.0      44.0    1610612748     114.0        0.507
# ...             ...       ...       ...           ...       ...          ...
# 17673         0.517      35.0      51.0    1610612758     106.0        0.378
# 17674         0.262      20.0      47.0    1610612747     123.0        0.475
# 17675         0.444      22.0      40.0    1610612753     125.0        0.526
# 17676         0.273      26.0      49.0    1610612745     109.0        0.375
# 17677         0.417      30.0      30.0    1610612754     132.0        0.516
#
#        FT_PCT_away  FG3_PCT_away  AST_away  REB_away  HOME_TEAM_WINS
# 1206         0.643         0.314      23.0      46.0               0
# 1207         0.955         0.424      26.0      35.0               0
# 1208         0.857         0.359      25.0      42.0               0
# 1209         0.759         0.333      23.0      43.0               1
# 1210         0.912         0.407      29.0      37.0               1
# ...            ...           ...       ...       ...             ...
# 17673        0.780         0.353      24.0      35.0               1
# 17674        0.633         0.303      32.0      58.0               0
# 17675        0.714         0.361      29.0      47.0               0
# 17676        0.800         0.229      21.0      52.0               0
# 17677        0.788         0.370      26.0      47.0               0
#
# [1241 rows x 17 columns]

# %% [markdown]
# # Prelimary Machine Learning

# %%
np.random.seed(42)  
# select the predictor variables and target variables to be used with regression
predictors = ['FG_PCT_home','FT_PCT_home','FG3_PCT_home','AST_home', 'REB_home', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away', 'AST_away', 'REB_away']
#dropping categortical features, such as GAME_ID,HOME_TEAM_ID, and a few more. 
target = 'HOME_TEAM_WINS'
X = df[predictors].values
y = df[target].values

# %%
# KNN can be slow, so get a random sample of the full data set
indexes = np.random.choice(y.size, size=10000)
X_mini = X[indexes]
y_mini = y[indexes]

# %%
# Split the data into training and test sets, and scale
scaler = StandardScaler()

# unscaled version (note that scaling is only used on predictor variables)
X_train_raw, X_test_raw, y_train, y_test = train_test_split(X_mini, y_mini, test_size=0.30, random_state=42)

# scaled version
X_train = scaler.fit_transform(X_train_raw)
X_test = scaler.transform(X_test_raw)

# %%
# sanity check
print(X_train.shape)
print(X_train[:3])
# Out:
# (7000, 10)
# [[-0.80000068  0.47504509 -2.00414024 -1.16536818  0.97470006 -0.74562742
#   -0.30180371 -0.90361939 -0.37293376  0.12726554]
#  [-0.02297033  0.64720376 -1.48049927  0.48250239 -0.92063105 -0.69061735
#   -0.42014595  0.6924874  -0.37293376  0.72616218]
#  [-0.14658879  0.46491811 -0.04921394  0.48250239  1.55787886 -1.14903458
#   -0.54835005  0.12498276 -0.37293376  0.42671386]]

# %%
sns.scatterplot(x="FT_PCT_home", y="HOME_TEAM_WINS", data=df)
# Out:
# <AxesSubplot:xlabel='FT_PCT_home', ylabel='HOME_TEAM_WINS'>
